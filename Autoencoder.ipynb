# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import umap
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model

# %% [markdown]
# # Load data

# %%
# !mkdir data
# !curl https://zenodo.org/record/3701939/files/BEELINE-data.zip?download=1 -o data/BEELINE-data.zip
# !unzip -d data/ data/BEELINE-data.zip

# %%
expression_file= './data/BEELINE-data/inputs/scRNA-Seq/mHSC-E/ExpressionData.csv'
data = pd.read_csv(expression_file, header=0, index_col=0)
print(np.shape(data))
data.head()
# Out:
# (4762, 1071)
#         HSPC_025  HSPC_031  LT_HSC_001  HSPC_001  HSPC_008  HSPC_014  \
# CLEC1B  0.000000  0.000000    0.000000  0.000000  1.172368  0.000000
# KDM3A   4.891604  6.877725    0.000000  0.000000  8.313856  2.209467
# CORO2B  1.426148  0.000000    8.178374  9.475577  1.172368  0.000000
# DEPP1   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# CLEC9A  0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
#
#         HSPC_020  LT_HSC_002  HSPC_002  HSPC_021  ...  Prog_815  Prog_821  \
# CLEC1B       0.0         0.0       0.0  0.000000  ...       0.0   0.00000
# KDM3A        0.0         0.0       0.0  7.235246  ...       0.0   0.74909
# CORO2B       0.0         0.0       0.0  5.689959  ...       0.0   0.00000
# DEPP1        0.0         0.0       0.0  0.000000  ...       0.0   0.00000
# CLEC9A       0.0         0.0       0.0  0.000000  ...       0.0   0.00000
#
#         Prog_827  Prog_839  Prog_851  Prog_816  Prog_822  Prog_828  Prog_834  \
# ...

# %%
time_file= './data/BEELINE-data/inputs/scRNA-Seq/mHSC-E/PseudoTime.csv'
slingshot_pseudotime = pd.read_csv(time_file, header=0, index_col=0)
slingshot_pseudotime.head()
# Out:
#             PseudoTime
# HSPC_025      0.065099
# HSPC_031      0.060365
# LT_HSC_001    0.037189
# HSPC_001      0.048053
# HSPC_008      0.055819

# %%
data_norm=np.log(1+data.values)
umaper = umap.UMAP()
embedding = umaper.fit_transform(data_norm)
plt.scatter(embedding[:, 0], embedding[:, 1])
plt.title('UMAP projection of the dataset', fontsize=24)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-c464383ab0c8> in <module>
#       1 data_norm=np.log(1+data.values)
# ----> 2 umaper = umap.UMAP()
#       3 embedding = umaper.fit_transform(data_norm)
#       4 plt.scatter(embedding[:, 0], embedding[:, 1])
#       5 plt.title('UMAP projection of the dataset', fontsize=24)
#
# AttributeError: module 'umap' has no attribute 'UMAP'
